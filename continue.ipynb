# %% [markdown]
# - improving and maintaning a good work-life balance (provide percentage). For example, they travel rarely
# - los que tienen remote work tienen más satisfaction
# - HR es el departamento con menos satisfacción lo que confirma que es una cuestión de cultura y ambiente
# - cuanto más lejos, mayor satisfacción ¿tendrán trabajo remoto?
# - si bien es poca la diferencia, la gente que está medianamente involved en el job, tiene mayor environment satisfaction: so continue - - distributing the work load equitativamente
# - cuanto menos training, menos environment satisfaction
# - healthcare representative: puesto con más satisfaction. A destacar, es el puesto con menos attrition, tiene un bussines travel medio y a excepción de los puestos de manager y director, es el dept con mejores salarios
#
#
# Conclusiones presentación:
# - continue trabajando en la work-life balance: ba´sandonos en bussines travel, w-lb y work load

# %%
abc[abc['department'] == 'human resources']['environmentsatisfaction'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
comprobación = abc.groupby('department')['environmentsatisfaction'].value_counts()

# %%
print(comprobación)
# Out:
# department              environmentsatisfaction
# human resources         3                           25
#                         2                           12
#                         4                           11
#                         1                           10
# research & development  4                          309
#                         3                          296
#                         1                          206
#                         2                          190
# sales                   4                          137
#                         3                          129
#                         1                           99
#                         2                           99
# Name: count, dtype: int64

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
abc = pd.read_csv('df_definitivo.csv', index_col=0)

# %%
# Satisfação no ambiente de trabalho por departamento
plt.figure(figsize=(10, 6))
sns.boxplot(data=abc, x='department', y='environmentsatisfaction')
plt.xticks(rotation=45)
plt.xlabel('Departamento')
plt.ylabel('Satisfação com o Ambiente')
plt.title('Distribuição da Satisfação com o Ambiente por Departamento')
plt.tight_layout()
plt.show()

# %%
categoricas = ['gender', 'overtime', 'maritalstatus', 'educationfield', 'jobrole', 'department', 'businesstravel', 'remotework']

for col in categoricas:
    plt.figure(figsize=(8,4))
    sns.countplot(data=abc, x=col, hue='buen_ambiente', palette='crest')
    plt.title(f'{col} según buen ambiente laboral')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
numericas = ['age', 'monthlyincome_$', 'distancefromhome', 'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion', 'yearswithcurrmanager']

for col in numericas:
    plt.figure(figsize=(8,4))
    sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
    plt.title(f'{col} según buen ambiente laboral')
    plt.tight_layout()
    plt.show();
# Out:
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3241603337.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=abc, x='buen_ambiente', y=col, palette='crest')

# %%
# Filtramos solo columnas numéricas
num_cols = abc.select_dtypes(include=np.number)

# Matriz de correlación
corr = num_cols.corr()

# Visualizamos solo las correlaciones con nuestras tres variables clave
plt.figure(figsize=(10,6))
sns.heatmap(corr[['environmentsatisfaction', 'jobsatisfaction', 'jobinvolvement']],
            annot=True, cmap='crest', vmin=-1, vmax=1)
plt.title('Correlación con ambiente laboral')
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 ¿Qué significa esto?
# Aunque parezca decepcionante, esto es útil porque sugiere que el ambiente laboral no depende tanto de los factores numéricos cuantificables, sino probablemente de factores cualitativos o culturales, como:
#
# El tipo de liderazgo
#
# La flexibilidad del horario o el teletrabajo
#
# El trato entre compañeros
#
# La presión o carga de trabajo
#
# El rol desempeñado

# %%
cols = ['attrition', 'businesstravel', 'salary']

for col in cols:
    plt.figure(figsize=(8,4))
    sns.barplot(data=abc, x='jobrole', y=col, color='blue')
    plt.title(f'Relación de {col} con jobrole')
    plt.xlabel('Puesto de trabajo')
    plt.xticks(rotation=90)

# %%
cat_cols = ['jobrole', 'overtime', 'department', 'remotework', 'maritalstatus']

for col in cat_cols:
    proporciones = abc.groupby(col)['buen_ambiente'].mean().sort_values(ascending=False)
    plt.figure(figsize=(8,4))
    sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')
    plt.title(f'Proporción de buen ambiente laboral por {col}')
    plt.xlabel('Proporción buen ambiente')
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3122484812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3122484812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3122484812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3122484812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')
# C:\Users\irene\AppData\Local\Temp\ipykernel_20632\3122484812.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=proporciones.values, y=proporciones.index, palette='crest')

# %%
abc = pd.read_csv('df_definitivo.csv', index_col=0)

# %%
empleados = abc.loc[abc['attrition'] == 'No',:]

# %%
abc.sample(3)
# Out:
#       age attrition businesstravel   dailyrate              department  \
# 1580   41        No            NaN  556.256661  research & development
# 1460   44        No  travel_rarely  556.256661                   sales
# 1295   30        No  travel_rarely  470.269841  research & development
#
#       distancefromhome  education    educationfield  employeenumber  \
# 1580                 2          4  Technical Degree            1581
# 1460                12          4         Marketing            1461
# 1295                17          2               NaN            1296
#
#       environmentsatisfaction  gender  jobinvolvement  joblevel  \
# 1580                        4  Female               2         2
# 1460                        2    Male               3         2
# 1295                        3    Male               3         2
#
#                         jobrole  jobsatisfaction maritalstatus  \
# 1580  healthcare representative                3        single
# 1460            sales executive                4      divorced
# 1295      laboratory technician                1           NaN
#
#       monthlyincome_$  monthlyrate_$  numcompaniesworked overtime  \
# 1580       4492.84000       11681.39                   1       No
# 1460      11125.13322       11681.39                   3  Unknown
# 1295       3798.33000        9875.67                   1  Unknown
#
#       percentsalaryhike  performancerating  relationshipsatisfaction  \
# 1580                 11                3.0                         1
# 1460                 12                0.0                         3
# 1295                 12                3.0                         4
#
#      standardhours  stockoptionlevel  trainingtimeslastyear worklifebalance  \
# 1580     Part Time                 0                      4             3.0
# 1460     Part Time                 2                      4             3.0
# 1295     Part Time                 1                      2         Unknown
#
#       yearsatcompany  yearsincurrentrole  yearssincelastpromotion  \
# 1580              20                 7.0                       11
# 1460               0                 0.0                        0
# 1295              10                 1.0                        1
#
#       yearswithcurrmanager  datebirth    salary  remotework
# 1580                    10       1984  53914.11       False
# 1460                     0       1981  53914.11       False
# 1295                     8       1995  45580.00       False

# %%
empleados_contentos = abc.groupby("environmentsatisfaction")

# %%
empleados_contentos.ngroups
# Out:
# 4

# %%
empleados_contentos[['jobinvolvement', 'jobsatisfaction', 'attrition']].count().reset_index()
# Out:
#    environmentsatisfaction  jobinvolvement  jobsatisfaction  attrition
# 0                        1             332              332        332
# 1                        2             319              319        319
# 2                        3             477              477        477
# 3                        4             486              486        486

# %%
condiciones = abc[
    (abc['attrition'] == 'No') &
    (abc['environmentsatisfaction'] >= 3) &
    (abc['jobinvolvement'] >= 3) &
    (abc['jobsatisfaction'] >= 3)
]

# %%
condiciones.head()
# Out:
#     age attrition businesstravel    dailyrate              department  \
# 2    44        No  travel_rarely  1984.253968  research & development
# 5    50        No            NaN  1771.920635  research & development
# 15   42        No  travel_rarely  1861.373016                     NaN
# 22   38        No            NaN  1032.487286  research & development
# 23   49        No            NaN  1728.380952                     NaN
#
#     distancefromhome  education    educationfield  employeenumber  \
# 2                  4          2  Technical Degree               3
# 5                 22          3           Medical               6
# 15                 2          4               NaN              16
# 22                 8          3               NaN              23
# 23                 2          2             Other              24
#
#     environmentsatisfaction  gender  jobinvolvement  joblevel  \
# 2                         3    Male               3         5
# 5                         4  Female               3         4
# 15                        3  Female               3         5
# 22                        3  Female               3         3
# 23                        3  Female               3         4
#
#                       jobrole  jobsatisfaction maritalstatus  monthlyincome_$  \
# 2                     manager                4       married     39685.079365
# 5                     manager                4           NaN     14311.670000
# 15                    manager                3           NaN     15034.170000
# 22  healthcare representative                3      divorced     20649.745724
# 23                    manager                4       married     34567.619048
#
#     monthlyrate_$  numcompaniesworked overtime  percentsalaryhike  \
# 2        41669.33                   1       No                 11
# 5        37210.33                   3       No                 11
# 15       39088.83                   0       No                 14
# 22       21682.23                   1  Unknown                 13
# 23       36296.00                   1  Unknown                 11
#
#     performancerating  relationshipsatisfaction standardhours  \
# 2                 3.0                         4       Unknown
# 5                 3.0                         2     Full Time
# 15                3.0                         4     Full Time
# 22                0.0                         2       Unknown
# 23                3.0                         3     Full Time
#
#     stockoptionlevel  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 2                  0                      3         Unknown              22
# 5                  1                      3             3.0              22
# 15                 0                      2             3.0              20
# 22                 3                      2             3.0              17
# 23                 1                      3             2.0              26
#
#     yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 2                 11.0                       11                    15
# 5                  4.0                        4                     7
# 15                 1.0                        1                    12
# 22                12.0                       12                     8
# 23                 3.0                        3                     0
#
#     datebirth     salary  remotework
# 2        1981  192320.00        True
# 5        1975  171740.04        True
# 15       1983  180410.00       False
# 22       1987  100071.84        True
# 23       1976  167520.00       False

# %%
sns.countplot(x = "remotework", 
              data = abc, 
              color = "purple");

# %%
sns.countplot(x = "worklifebalance", 
              data = condiciones, 
              color = "yellow");

# %%
sns.countplot(x = "worklifebalance", 
              data = abc, 
              color = "yellow");

# %%
sns.countplot(x = "businesstravel", 
              data = condiciones, 
              color = "green");

# %%
sns.countplot(x = "businesstravel", 
              data = abc, 
              color = "green");

# %%
sns.boxplot(x = "salary", 
            data = condiciones, 
            color = "turquoise", 
            );

# %%
sns.boxplot(x = "salary", 
            data = abc, 
            color = "turquoise", 
            );

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data=condiciones, x='yearssincelastpromotion', kde=True, color='purple')
plt.title('Años desde última promoción (Empleados que se quedaron)')
plt.xlabel('Años sin promoción')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(
    data=abc,  # Usamos el dataframe completo (no filtrado)
    x='attrition', 
    y='yearssincelastpromotion',
    palette={'Yes': 'red', 'No': 'green'}  # Colores para claridad
)
plt.title('Años desde última promoción: Attrition vs. No Attrition')
plt.xlabel('¿Dejó la empresa? (Yes/No)')
plt.ylabel('Años sin promoción')
plt.show();
# Out:
# C:\Users\irene\AppData\Local\Temp\ipykernel_31056\4275456494.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
abc_empleados = abc['attrition'] == 'No'

# %%
df_abc_empleados = abc[abc_empleados]

# %%
df_abc_empleados.sample(3)
# Out:
#      age attrition businesstravel   dailyrate              department  \
# 738   48        No  travel_rarely  556.256661  research & development
# 987   35        No     non-travel  290.035510                   sales
# 881   32        No            NaN  556.256661                   sales
#
#      distancefromhome  education    educationfield  employeenumber  \
# 738                 2          4  Technical Degree             739
# 987                 8          1     Life Sciences             988
# 881                25          2               NaN             882
#
#      environmentsatisfaction  gender  jobinvolvement  joblevel  \
# 738                        4    Male               3         2
# 987                        2  Female               2         1
# 881                        4  Female               3         2
#
#                     jobrole  jobsatisfaction maritalstatus  monthlyincome_$  \
# 738  manufacturing director                4      divorced     11125.133220
# 987    sales representative                4           NaN      5800.710195
# 881         sales executive                3           NaN      4492.840000
#
#      monthlyrate_$  numcompaniesworked overtime  percentsalaryhike  \
# 738       11681.39                   2  Unknown                 11
# 987        6090.75                   0  Unknown                 19
# 881       11681.39                   7  Unknown                 12
#
#      performancerating  relationshipsatisfaction standardhours  \
# 738                3.0                         3     Part Time
# 987                3.0                         4     Part Time
# 881                3.0                         2     Part Time
#
#      stockoptionlevel  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 738                 1                      3             2.0               6
# 987                 0                      2             2.0               2
# 881                 1                      2             4.0               2
#
#      yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 738                 1.0                        1                     4
# 987                 2.0                        2                     2
# 881                 2.0                        2                     2
#
#      datebirth    salary  remotework
# 738       1977  53914.11        True
# 987       1990  28111.13       False
# 881       1993  53914.08       False

# %%
empleados.head()
# Out:
#    age attrition businesstravel    dailyrate              department  \
# 0   53        No            NaN  2015.722222  research & development
# 1   54        No            NaN  2063.388889                     NaN
# 2   44        No  travel_rarely  1984.253968  research & development
# 3   49        No  travel_rarely  1771.404762  research & development
# 4   48        No            NaN  1582.771346                   sales
#
#    distancefromhome  education    educationfield  employeenumber  \
# 0                 6          3               NaN               1
# 1                 1          4     Life Sciences               2
# 2                 4          2  Technical Degree               3
# 3                 2          4           Medical               4
# 4                 3          3  Technical Degree               5
#
#    environmentsatisfaction  gender  jobinvolvement  joblevel  \
# 0                        1    Male               3         5
# 1                        3    Male               2         5
# 2                        3    Male               3         5
# 3                        1  Female               3         4
# 4                        1  Female               4         4
#
#              jobrole  jobsatisfaction maritalstatus  monthlyincome_$  \
# 0  research director                3           NaN     16280.830000
# 1            manager                3           NaN     41267.777778
# 2            manager                4       married     39685.079365
# 3  research director                3       married     14307.500000
# 4    sales executive                1      divorced     12783.920000
#
#    monthlyrate_$  numcompaniesworked overtime  percentsalaryhike  \
# 0       42330.17                   7       No                 13
# 1       43331.17                   0  Unknown                 14
# 2       41669.33                   1       No                 11
# 3       37199.50                   3  Unknown                 19
# 4       33238.20                   2       No                 12
#
#    performancerating  relationshipsatisfaction standardhours  \
# 0                3.0                         3     Full Time
# 1                3.0                         1       Unknown
# 2                3.0                         4       Unknown
# 3                3.0                         2     Full Time
# 4                3.0                         4     Full Time
#
#    stockoptionlevel  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0                 0                      5             3.0              20
# 1                 1                      5             3.0              33
# 2                 0                      3         Unknown              22
# 3                 2                      2         Unknown              20
# 4                 1                      5             3.0              19
#
#    yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                15.0                       15                    15
# 1                11.0                       11                     9
# 2                11.0                       11                    15
# 3                 5.0                        5                     6
# 4                 2.0                        2                     8
#
#    datebirth     salary  remotework
# 0       1972  195370.00        True
# 1       1971  199990.00        True
# 2       1981  192320.00        True
# 3       1976  171690.00       False
# 4       1977  153407.04       False

# %%
correlacion = abc.corr('pearson', numeric_only=True)

# %%
correlacion1 = abc.corr('kendall', numeric_only=True)

# %%
mask = np.triu(np.ones_like(correlacion1, dtype=bool))

# %%
plt.figure(figsize = (15, 15))

# convertimos nuestra matriz de correlación a una gráfica
sns.heatmap(correlacion1, # sobre que datos queremos hacer el heatmap
            annot = True, # para que nos muestre los valores de cada una de las celdas del heatmap
            fmt = ".2f",  # para que nos redondee a dos decimales
            cmap = "mako", # para establecer el color de la gráfica
            vmax = 1, # para indicar cual es el valor máximo de nuestra escala de colores
            vmin = -1,
            mask= mask); # para ident

# %%
heatmap_correlaciones(abc, columnas=['salary', 'jobinvolvement', 'environmentsatisfaction'])
