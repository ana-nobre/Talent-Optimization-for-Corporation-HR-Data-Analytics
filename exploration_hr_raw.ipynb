# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# %%
df_datos_abc=pd.read_csv("hr_raw_data.csv",index_col=0)

# %% [markdown]
# Comentarios:
# - 1678 filas
# - 41 columnas
# - size: 68798
#
# Investigar columna 'attrition'

# %%
df_datos_abc.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# ...

# %%
df_datos_abc.shape # filas #columnas
# Out:
# (1678, 41)

# %%
df_datos_abc.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df_datos_abc.size
# Out:
# 68798

# %%
df_datos_abc.info() #info sobre valores not null y tipo de dato
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %%
df_datos_abc.isnull() #posición de los nulos
# Out:
#         age  attrition  businesstravel  dailyrate  department  \
# 0     False      False            True      False        True
# 1     False      False            True      False        True
# 2     False      False           False      False       False
# 3     False      False           False      False        True
# 4     False      False            True      False        True
# ...     ...        ...             ...        ...         ...
# 1673  False      False            True      False        True
# 1674  False      False            True      False        True
# 1675  False      False           False      False        True
# 1676  False      False           False      False        True
# 1677  False      False            True      False        True
#
#       distancefromhome  education  educationfield  employeecount  \
# 0                False      False            True          False
# 1                False      False           False          False
# ...

# %%
df_datos_abc.isnull().sum() #número de nulos que hay
# Out:
# age                            0
# attrition                      0
# businesstravel               801
# dailyrate                      0
# department                  1366
# distancefromhome               0
# education                      0
# educationfield               774
# employeecount                  0
# employeenumber                 0
# environmentsatisfaction        0
# gender                         0
# hourlyrate                  1267
# jobinvolvement                 0
# joblevel                       0
# jobrole                        0
# jobsatisfaction                0
# maritalstatus                675
# monthlyincome                489
# monthlyrate                    0
# numcompaniesworked             0
# over18                       938
# overtime                     696
# percentsalaryhike              0
# performancerating            200
# relationshipsatisfaction       0
# standardhours                351
# stockoptionlevel               0
# ...

# %%
df_datos_abc.isna().sum()/df_datos_abc.shape[0]*100
# Out:
# age                           0.000000
# attrition                     0.000000
# businesstravel               47.735399
# dailyrate                     0.000000
# department                   81.406436
# distancefromhome              0.000000
# education                     0.000000
# educationfield               46.126341
# employeecount                 0.000000
# employeenumber                0.000000
# environmentsatisfaction       0.000000
# gender                        0.000000
# hourlyrate                   75.506555
# jobinvolvement                0.000000
# joblevel                      0.000000
# jobrole                       0.000000
# jobsatisfaction               0.000000
# maritalstatus                40.226460
# monthlyincome                29.141836
# monthlyrate                   0.000000
# numcompaniesworked            0.000000
# over18                       55.899881
# overtime                     41.477950
# percentsalaryhike             0.000000
# ...

# %%
df_datos_abc.select_dtypes(include = 'int')
# Out:
#       distancefromhome  education  employeecount  employeenumber  \
# 0                    6          3              1               1
# 1                    1          4              1               2
# 2                    4          2              1               3
# 3                    2          4              1               4
# 4                    3          3              1               5
# ...                ...        ...            ...             ...
# 1673               -26          3              1             824
# 1674                26          4              1            1087
# 1675                15          3              1             528
# 1676                 4          3              1              76
# 1677                 2          2              1             401
#
#       environmentsatisfaction  gender  jobinvolvement  joblevel  \
# 0                           1       0               3         5
# ...

# %%
df_datos_abc.select_dtypes(include = 'float')
# Out:
#         dailyrate  hourlyrate  numberchildren
# 0     2015.722222         NaN             NaN
# 1     2063.388889         NaN             NaN
# 2     1984.253968         NaN             NaN
# 3     1771.404762         NaN             NaN
# 4     1582.771346         NaN             NaN
# ...           ...         ...             ...
# 1673   488.944444         NaN             NaN
# 1674  1973.984127         NaN             NaN
# 1675   290.035510         NaN             NaN
# 1676  1032.487286         NaN             NaN
# 1677   556.256661   69.532083             NaN
#
# [1678 rows x 3 columns]

# %%
df_datos_abc.select_dtypes(include = 'object')
# Out:
#      age attrition businesstravel                department    educationfield  \
# 0     51        No            NaN                       NaN               NaN
# 1     52        No            NaN                       NaN     Life Sciences
# 2     42        No  travel_rarely   Research & Development   Technical Degree
# 3     47        No  travel_rarely                       NaN           Medical
# 4     46        No            NaN                       NaN  Technical Degree
# ...   ..       ...            ...                       ...               ...
# 1673  43        No            NaN                       NaN           Medical
# 1674  47        No            NaN                       NaN               NaN
# 1675  29        No  travel_rarely                       NaN               NaN
# 1676  47        No  travel_rarely                       NaN     Life Sciences
# 1677  32        No            NaN                       NaN     Life Sciences
#
# ...

# %%
df_datos_abc.duplicated().sum() #64 filas duplicadas
# Out:
# 64

# %%
df_datos_abc.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1673     True
# 1674     True
# 1675     True
# 1676     True
# 1677     True
# Length: 1678, dtype: bool

# %%
df_datos_abc['educationfield'].duplicated().sum()
# Out:
# 1671

# %%
df_datos_abc['educationfield'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1673     True
# 1674     True
# 1675     True
# 1676     True
# 1677     True
# Name: educationfield, Length: 1678, dtype: bool

# %%
df_datos_abc.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df_datos_abc['employeenumber'].unique() #solo se puede hacer por columnas
# Out:
# 1303305

# %%
df_datos_abc['employeenumber'].duplicated().sum() #el mismo número de duplicados que hay en toda la tabla
# Out:
# 64

# %%
df_datos_abc[df_datos_abc.duplicated(subset = 'employeenumber', keep = False)].sort_values('employeenumber')
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 60    36        No            NaN   610.174603        NaN                 5
# 1652  36        No            NaN   610.174603        NaN                 5
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
# ...   ..       ...            ...          ...        ...               ...
# 1638  48        No  travel_rarely   417.960317        NaN                 2
# 1657  45        No  travel_rarely   495.753968        NaN                 2
# 1568  45        No  travel_rarely   495.753968        NaN                 2
# 1671  31        No            NaN   556.256661        NaN                12
# 1607  31        No            NaN   556.256661        NaN                12
#
# ...

# %%
df_datos_abc[df_datos_abc.duplicated(subset = 'employeenumber', keep = False)].sort_values('employeenumber').head()
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 60    36        No            NaN   610.174603        NaN                 5
# 1652  36        No            NaN   610.174603        NaN                 5
# 1676  47        No  travel_rarely  1032.487286        NaN                 4
#
#       education educationfield  employeecount  employeenumber  \
# 8             5            NaN              1               9
# 1656          5            NaN              1               9
# 60            2            NaN              1              61
# 1652          2            NaN              1              61
# 1676          3  Life Sciences              1              76
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# ...

# %%
df_datos_abc[[8,1656]]
# Out:
# Running cells with 'conector (Python 3.11.13)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n conector ipykernel --update-deps --force-reinstall'
