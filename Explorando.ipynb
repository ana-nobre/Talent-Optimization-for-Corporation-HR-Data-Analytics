# %%
import pandas as pd

import numpy as np

# %%
df_datos_abc=pd.read_csv("hr_raw_data.csv",index_col=0)

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Nuestra misión es identificar factores clave que influyen en la satisfacción en el trabajo y en la retención de empleados
#
# Comentarios sobre el csv:
# - 1678 filas
# - 41 columnas
# - size: 68798
# - employee number PK
# - NaN = Null
#
# Analise sobre el csv:
# - relationshipsatisfaction'
# - Investigar columna 'attrition'
# - Investigar columna 'dailyrate'
# - Investigar columna 'employeecount'
# - Investigar columna 'same as monthy income'
# - Distance from Home: cual es el rango?
# - Education: a que nivel equipara?
# - Analizar la columna years at company con la columna attrition (las dos tienen temas en comum)
# - Calcular años en el role actual (years in current role) - Calcular los years at company & years since last promotion
# - Years since last promotion and years with current manager (investigar promociones internas para mandos superiores - current manager cambio o no)

# %%
df_datos_abc.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  ...  yearsatcompany  yearsincurrentrole  \
# 0               1  ...              20                 NaN
# 1               2  ...              33                 NaN
# 2               3  ...              22                 NaN
# 3               4  ...              20                 NaN
# 4               5  ...              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15            16280,83$
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6            14307,50$
# 4                        2                     8            12783,92$
#
#   datebirth      salary                       roledepartament numberchildren  \
# 0      1972  195370,00$                                   NaN            NaN
# 1      1971  199990,00$                                   NaN            NaN
# 2      1981  192320,00$   ManaGER  -  Research & Development             NaN
# 3      1976  171690,00$                                   NaN            NaN
# 4      1977         NaN                                   NaN            NaN
#
#   remotework
# 0        Yes
# 1          1
# 2          1
# 3      False
# 4          0
#
# [5 rows x 41 columns]

# %%
df_datos_abc.shape # filas #columnas
# Out:
# (1678, 41)

# %%
df_datos_abc.size
# Out:
# 68798

# %%
df_datos_abc.dtypes
# Out:
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# standardhours                object
# stockoptionlevel              int64
# totalworkingyears            object
# trainingtimeslastyear         int64
# worklifebalance              object
# yearsatcompany                int64
# yearsincurrentrole           object
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome          object
# datebirth                     int64
# salary                       object
# roledepartament              object
# numberchildren              float64
# remotework                   object
# dtype: object

# %%
df_datos_abc[df_datos_abc['employeenumber'] == 9]
# Out:
#      age attrition businesstravel   dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.18254        NaN                 2
# 1656  41        No            NaN  1712.18254        NaN                 2
#
#       education educationfield  employeecount  employeenumber  ...  \
# 8             5            NaN              1               9  ...
# 1656          5            NaN              1               9  ...
#
#       yearsatcompany  yearsincurrentrole  yearssincelastpromotion  \
# 8                 18                 NaN                       11
# 1656              18                 NaN                       11
#
#       yearswithcurrmanager  sameasmonthlyincome datebirth      salary  \
# 8                        8            13829,17$      1982  165950,00$
# 1656                     8            13829,17$      1982  165950,00$
#
#      roledepartament numberchildren remotework
# 8                NaN            NaN       True
# 1656             NaN            NaN       True
#
# [2 rows x 41 columns]

# %%
df_datos_abc.columns
# Out:
# Index(['age', 'attrition', 'businesstravel', 'dailyrate', 'department',
#        'distancefromhome', 'education', 'educationfield', 'employeecount',
#        'employeenumber', 'environmentsatisfaction', 'gender', 'hourlyrate',
#        'jobinvolvement', 'joblevel', 'jobrole', 'jobsatisfaction',
#        'maritalstatus', 'monthlyincome', 'monthlyrate', 'numcompaniesworked',
#        'over18', 'overtime', 'percentsalaryhike', 'performancerating',
#        'relationshipsatisfaction', 'standardhours', 'stockoptionlevel',
#        'totalworkingyears', 'trainingtimeslastyear', 'worklifebalance',
#        'yearsatcompany', 'yearsincurrentrole', 'yearssincelastpromotion',
#        'yearswithcurrmanager', 'sameasmonthlyincome', 'datebirth', 'salary',
#        'roledepartament', 'numberchildren', 'remotework'],
#       dtype='object')

# %%
df_filtrado = df_datos_abc[['education','jobsatisfaction','yearssincelastpromotion','employeenumber']]
df_filtrado
# Out:
#       education  jobsatisfaction  yearssincelastpromotion  employeenumber
# 0             3                3                       15               1
# 1             4                3                       11               2
# 2             2                4                       11               3
# 3             4                3                        5               4
# 4             3                1                        2               5
# ...         ...              ...                      ...             ...
# 1673          3                3                        1             824
# 1674          4                3                        1            1087
# 1675          3                4                        1             528
# 1676          3                2                       14              76
# 1677          2                3                        0             401
#
# [1678 rows x 4 columns]

# %%
df_id_empleado = df_filtrado.sort_values
df_id_empleado
# Out:
# <bound method DataFrame.sort_values of       education  jobsatisfaction  yearssincelastpromotion  employeenumber
# 0             3                3                       15               1
# 1             4                3                       11               2
# 2             2                4                       11               3
# 3             4                3                        5               4
# 4             3                1                        2               5
# ...         ...              ...                      ...             ...
# 1673          3                3                        1             824
# 1674          4                3                        1            1087
# 1675          3                4                        1             528
# 1676          3                2                       14              76
# 1677          2                3                        0             401
#
# [1678 rows x 4 columns]>

# %%
df_filtrado = df_datos_abc[['education', 'jobsatisfaction', 'yearssincelastpromotion', 'employeenumber']]
df_filtrado = df_filtrado.sort_values(by='employeenumber')
df_filtrado
# Out:
#       education  jobsatisfaction  yearssincelastpromotion  employeenumber
# 0             3                3                       15               1
# 1             4                3                       11               2
# 2             2                4                       11               3
# 3             4                3                        5               4
# 4             3                1                        2               5
# ...         ...              ...                      ...             ...
# 1609          1                4                        3            1610
# 1610          2                2                        0            1611
# 1611          5                3                        0            1612
# 1612          4                4                        0            1613
# 1613          2                3                        0            1614
#
# [1678 rows x 4 columns]

# %%
df_datos_abc[df_datos_abc.duplicated(subset = 'employeenumber', keep = False)].sort_values('employeenumber')

orden_duplicados = df_datos_abc[df_datos_abc.duplicated(subset = 'employeenumber', keep = False)].sort_values('employeenumber')
# Out:
#      age attrition businesstravel    dailyrate department  distancefromhome  \
# 8     41        No            NaN  1712.182540        NaN                 2
# 1656  41        No            NaN  1712.182540        NaN                 2
# 1652  36        No            NaN   610.174603        NaN                 5
# 60    36        No            NaN   610.174603        NaN                 5
# 75    47        No  travel_rarely  1032.487286        NaN                 4
# ...   ..       ...            ...          ...        ...               ...
# 1638  48        No  travel_rarely   417.960317        NaN                 2
# 1657  45        No  travel_rarely   495.753968        NaN                 2
# 1568  45        No  travel_rarely   495.753968        NaN                 2
# 1607  31        No            NaN   556.256661        NaN                12
# 1671  31        No            NaN   556.256661        NaN                12
#
#       education educationfield  employeecount  employeenumber  \
# 8             5            NaN              1               9
# 1656          5            NaN              1               9
# 1652          2            NaN              1              61
# 60            2            NaN              1              61
# 75            3  Life Sciences              1              76
# ...         ...            ...            ...             ...
# 1638          5            NaN              1            1568
# 1657          3          Other              1            1569
# 1568          3          Other              1            1569
# 1607          3        Medical              1            1608
# 1671          3        Medical              1            1608
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 8                           2       1         NaN               3         4
# 1656                        2       1         NaN               3         4
# 1652                        4       0         NaN               3         2
# 60                          4       0         NaN               3         2
# 75                          3       1         NaN               2         3
# ...                       ...     ...         ...             ...       ...
# 1638                        2       1         NaN               3         2
# 1657                        4       0         NaN               3         2
# 1568                        4       0         NaN               3         2
# 1607                        4       1         NaN               3         2
# 1671                        4       1         NaN               3         2
#
#                           jobrole  jobsatisfaction maritalstatus  \
# 8                        mANAGEr                 1       Married
# 1656                     mANAGEr                 1       Married
# 1652       lAboratORy TeChNiCiaN                 2        Single
# 60         lAboratORy TeChNiCiaN                 2        Single
# 75        maNufACTURING DIREctOr                 2      Divorced
# ...                           ...              ...           ...
# 1638             sALES EXEcuTIVe                 4       Married
# 1657             sAles executiVe                 2           NaN
# 1568             sAles executiVe                 2           NaN
# 1607   HEaltHCarE REPreSENtAtIve                 4           NaN
# 1671   HEaltHCarE REPreSENtAtIve                 4           NaN
#
#      monthlyincome monthlyrate  numcompaniesworked over18 overtime  \
# 8        13829,17$   35955,83$                   7    NaN       No
# 1656     13829,17$   35955,83$                   7    NaN       No
# 1652      4928,33$   12813,67$                   8      Y       No
# 60        4928,33$   12813,67$                   8      Y       No
# 75        8339,32$   21682,23$                   8    NaN      Yes
# ...            ...         ...                 ...    ...      ...
# 1638      3375,83$    8777,17$                   2    NaN       No
# 1657           NaN   10410,83$                   0    NaN       No
# 1568           NaN   10410,83$                   0    NaN       No
# 1607           NaN   11681,39$                   0    NaN      NaN
# 1671           NaN   11681,39$                   0    NaN      NaN
#
#       percentsalaryhike performancerating  relationshipsatisfaction  \
# 8                    16               3,0                         2
# 1656                 16               3,0                         2
# 1652                 16               3,0                         4
# 60                   16               3,0                         4
# 75                   12               NaN                         3
# ...                 ...               ...                       ...
# 1638                 14               3,0                         1
# 1657                 19               3,0                         2
# 1568                 19               3,0                         2
# 1607                 11               3,0                         3
# 1671                 11               3,0                         3
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 8        Full Time                 1              22,0                      2
# 1656     Full Time                 1              22,0                      2
# 1652     Full Time                 0              16,0                      3
# 60       Full Time                 0              16,0                      3
# 75       Part Time                 1               NaN                      4
# ...            ...               ...               ...                    ...
# 1638     Part Time                 1              14,0                      2
# 1657     Part Time                 1               NaN                      3
# 1568     Part Time                 1               NaN                      3
# 1607     Part Time                 2              10,0                      2
# 1671     Part Time                 2              10,0                      2
#
#      worklifebalance  yearsatcompany yearsincurrentrole  \
# 8                3,0              18                NaN
# 1656             3,0              18                NaN
# 1652             4,0              13                NaN
# 60               4,0              13                NaN
# 75               3,0              22                NaN
# ...              ...             ...                ...
# 1638             3,0               9                NaN
# 1657             4,0               8                NaN
# 1568             4,0               8                NaN
# 1607             1,0               9                NaN
# 1671             1,0               9                NaN
#
#       yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# 8                          11                     8           13829,17$
# 1656                       11                     8           13829,17$
# 1652                        3                     7            4928,33$
# 60                          3                     7            4928,33$
# 75                         14                    10            8339,32$
# ...                       ...                   ...                 ...
# 1638                        6                     7            3375,83$
# 1657                        3                     7                 NaN
# 1568                        3                     7                 NaN
# 1607                        8                     5                 NaN
# 1671                        8                     5                 NaN
#
#       datebirth      salary roledepartament  numberchildren remotework
# 8          1982  165950,00$             NaN             NaN       True
# 1656       1982  165950,00$             NaN             NaN       True
# 1652       1987   59140,00$             NaN             NaN          1
# 60         1987   59140,00$             NaN             NaN          1
# 75         1976  100071,84$             NaN             NaN        Yes
# ...         ...         ...             ...             ...        ...
# 1638       1975   40510,00$             NaN             NaN       True
# 1657       1978   48050,00$             NaN             NaN      False
# 1568       1978   48050,00$             NaN             NaN      False
# 1607       1992   53914,11$             NaN             NaN       True
# 1671       1992   53914,11$             NaN             NaN       True
#
# [128 rows x 41 columns]

# %%
df_datos_abc[df_datos_abc.duplicated(subset='employeenumber', keep=False)].sort_values('employeenumber')

x = df_datos_abc[df_datos_abc.duplicated(subset='employeenumber', keep=False)].sort_values('employeenumber')

# %%
x.duplicated().sum()
# Out:
# np.int64(64)

# %%
x['employeenumber'].value_counts() # ID y cuantas veces estan duplicados
# Out:
# employeenumber
# 9       2
# 61      2
# 76      2
# 108     2
# 112     2
#        ..
# 1532    2
# 1567    2
# 1568    2
# 1569    2
# 1608    2
# Name: count, Length: 64, dtype: int64
