# %% [markdown]
# {      # Retribuicion
#     "Compensation and Benefits": [
#         "salary",
#         "monthlyincome_$",
#         "monthlyrate_$",
#         "dailyrate",
#         "stockoptionlevel"],
#
#         # Educación y Formación
#     "Education and Training": [
#         "education",
#         "educationfield",
#         "trainingtimeslastyear"],
#
#     # Condiciones Laborales
#     "Work Conditions": [
#         "businesstravel",
#         "distancefromhome",
#         "overtime",
#         "remotework"],
#
#      # Función y Departamento
#     "Function and Department": [
#         "department",
#         "jobrole",
#         "joblevel",
#         "roledepartament"],
#
#     # Satisfacción y Compromiso
#     "Satisfaction and Engagement": [
#         "environmentsatisfaction",
#         "jobsatisfaction",
#         "relationshipsatisfaction",
#         "jobinvolvement",
#         "performancerating",
#         "worklifebalance"],
#
#     # Datos Personales
#     "Personal Data": [
#         "gender",
#         "maritalstatus",
#         "datebirth",
#         "employeenumber"],
#
#     # Antigüedad General
#     "Tenure": [
#         "yearsatcompany",
#         "numcompaniesworked",
#         "standardhours"],
#
#     # Perspectivas de Crecimiento (Condiciones de carrera)
#     "Career Prospects": [
#         "yearsincurrentrole",
#         "yearssincelastpromotion",
#         "yearswithcurrmanager",
#         "joblevel",
#         "trainingtimeslastyear",
#         "percentsalaryhike"],
#
#     # Variable Objetivo
#     "Target Variable": [
#         "attrition"]}
